# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
export_au=pd.read_csv('export_au.csv')
export_au.drop(columns=['Unnamed: 12'], inplace=True)
export_au['BEC']=export_au['BEC'].astype('int64')

# %%
export_au.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5227 entries, 0 to 5226
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   HS                      5227 non-null   int64
#  1   BEC                     5227 non-null   int64
#  2   Product label           5227 non-null   object
#  3   Exported value in 2012  5227 non-null   int64
#  4   Exported value in 2013  5227 non-null   int64
#  5   Exported value in 2014  5227 non-null   int64
#  6   Exported value in 2015  5227 non-null   int64
#  7   Exported value in 2016  5227 non-null   int64
#  8   Exported value in 2017  5227 non-null   int64
#  9   Exported value in 2018  5227 non-null   int64
#  10  Exported value in 2019  5227 non-null   int64
#  11  Exported value in 2020  5227 non-null   int64
#  12  Exported value in 2021  5227 non-null   int64
# dtypes: int64(12), object(1)
# memory usage: 531.0+ KB

# %%
export_au.describe()
# Out:
#                   HS            BEC  Exported value in 2012  \
# count    5227.000000    5227.000000            5.227000e+03
# mean   527257.376698  320536.078056            5.025416e+04
# std    282692.687294  201990.843399            1.094924e+06
# min     10121.000000       0.000000            0.000000e+00
# 25%    291445.000000  113201.000000            3.400000e+01
# 50%    550330.000000  311220.000000            4.430000e+02
# 75%    830670.000000  413202.000000            3.367500e+03
# max    999999.000000  999999.000000            5.919264e+07
#
#        Exported value in 2013  Exported value in 2014  Exported value in 2015  \
# count            5.227000e+03            5.227000e+03            5.227000e+03
# mean             4.910628e+04            4.834136e+04            3.660228e+04
# std              1.146330e+06            1.137146e+06            7.167692e+05
# min              0.000000e+00            0.000000e+00            0.000000e+00
# ...

# %%
export_au_describe=pd.DataFrame(export_au.describe())

# %%
export_au_describe=export_au_describe.iloc[:,2:13]

# %%
export_au_describe
# Out:
#        Exported value in 2012  Exported value in 2013  Exported value in 2014  \
# count            5.227000e+03            5.227000e+03            5.227000e+03
# mean             5.025416e+04            4.910628e+04            4.834136e+04
# std              1.094924e+06            1.146330e+06            1.137146e+06
# min              0.000000e+00            0.000000e+00            0.000000e+00
# 25%              3.400000e+01            2.850000e+01            2.500000e+01
# 50%              4.430000e+02            3.910000e+02            3.540000e+02
# 75%              3.367500e+03            3.110500e+03            2.965000e+03
# max              5.919264e+07            6.852271e+07            6.926062e+07
#
#        Exported value in 2015  Exported value in 2016  Exported value in 2017  \
# count            5.227000e+03            5.227000e+03            5.227000e+03
# mean             3.660228e+04            3.623288e+04            4.394915e+04
# ...

# %%
export_au_BEC=export_au.groupby('BEC').sum()

# %%
export_au_BEC
# Out:
#               HS  Exported value in 2012  Exported value in 2013  \
# BEC
# 0         711890                  755562                 1009486
# 212      8823980                  153321                  103982
# 312     42745272                  404674                  363402
# 512     16867785                  325689                  339424
# 612      1802060                    3769                    3287
# ...          ...                     ...                     ...
# 812020  13661531                   94126                   87463
# 813101    721110                      63                     140
# 813201    930690                   34875                   65557
# 813202   3103800                   10981                   18552
# 999999    999999                10044824                 8777678
#
#         Exported value in 2014  Exported value in 2015  \
# BEC
# 0                       640719                  630877
# 212                      95308                   85729
# ...

# %%
export_au_BEC.transpose()
# Out:
# BEC                      0        212       312       512      612     \
# HS                       711890  8823980  42745272  16867785  1802060
# Exported value in 2012   755562   153321    404674    325689     3769
# Exported value in 2013  1009486   103982    363402    339424     3287
# Exported value in 2014   640719    95308    352463    598611     5096
# Exported value in 2015   630877    85729    301078    372873     5543
# Exported value in 2016   735766    81876    324117    294489     2640
# Exported value in 2017   518517    85263    357792    351452     3199
# Exported value in 2018   609248    82488    404262    655641     2606
# Exported value in 2019   600536    87978    397921    646896     1187
# Exported value in 2020  1032862    93657    356975    360023     1161
# Exported value in 2021  1939936    94403    413554    439334     1587
#
# BEC                       712       1111       2111      3111      3112    \
# ...

# %%
sns.barplot(data=export_au_BEC.transpose())
# Out:
# <AxesSubplot:xlabel='BEC'>

# %%
sns.scatterplot(x=('Exported value in 2012','Exported value in 2012'), data=export_au_describe)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/hq/n1bxsy297pjfnb_sxvrk2k8r0000gn/T/ipykernel_2939/1290175777.py in <module>
# ----> 1 sns.scatterplot(x=('Exported value in 2012','Exported value in 2012'), data=export_au_describe)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     806
# ...
