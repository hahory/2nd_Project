# %%
import pandas as pd
import numpy as np

# %%
hs_bec_raw=pd.read_excel('hs_bec.xlsx', sheet_name=[1])
hs_bec_raw=pd.DataFrame(hs_bec_raw[1])
hs_bec_raw
# Out:
#       HS   HS4                                            HS4Desc     HS6  \
# 0     H5   101             Horses, asses, mules and hinnies; live   10121
# 1     H5   101             Horses, asses, mules and hinnies; live   10129
# 2     H5   101             Horses, asses, mules and hinnies; live   10130
# 3     H5   101             Horses, asses, mules and hinnies; live   10190
# 4     H5   102                               Bovine animals; live   10221
# ...   ..   ...                                                ...     ...
# 5382  H5  9702       Engravings, prints and lithographs; original  970200
# 5383  H5  9703  Sculptures and statuary; original, in any mate...  970300
# 5384  H5  9704  Stamps, postage or revenue; stamp-postmarks, f...  970400
# 5385  H5  9705  Collections and collectors' pieces; of zoologi...  970500
# 5386  H5  9706    Antiques; of an age exceeding one hundred years  970600
#
#                                                 HS6Desc  BEC5Code1  BEC5Code2  \
# ...

# %%
hs_bec=hs_bec_raw[['HS6','BEC5Code1']]
hs_bec.rename(columns={'HS6':'HS', 'BEC5Code1':'BEC'}, inplace=True)
hs_bec
# Out:
# /Users/ejju/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#           HS       BEC
# 0      10121  712010.0
# 1      10129    1111.0
# 2      10130    1111.0
# 3      10190    1111.0
# 4      10221  112010.0
# ...      ...       ...
# 5382  970200  713202.0
# 5383  970300  713202.0
# 5384  970400  813202.0
# 5385  970500  713202.0
# 5386  970600  713202.0
#
# [5387 rows x 2 columns]

# %%
hs_bec.isnull().sum()#null값이 2개 있음을 확인
# Out:
# HS     0
# BEC    2
# dtype: int64

# %%
hs_bec[(hs_bec['BEC'].isnull())]
#https://unipass.customs.go.kr에서 검색
#71.08-금(백금을 도금한 금을 포함하며, 가공하지 않은 것ㆍ반가공한 모양이나 가루 모양인 것으로 한정,.20-화폐용
#71.18 - 주화,.90-기타
# Out:
#           HS  BEC
# 3513  710820  NaN
# 3542  711890  NaN

# %%
hs_bec = hs_bec.fillna(0)

# %%
hs_bec.isnull().sum()
# Out:
# HS     0
# BEC    0
# dtype: int64

# %%
hs_bec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5387 entries, 0 to 5386
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HS      5387 non-null   int64
#  1   BEC     5387 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 84.3 KB

# %%
hs_bec['BEC'] =hs_bec['BEC'].astype('int64')

# %%
hs_bec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5387 entries, 0 to 5386
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HS      5387 non-null   int64
#  1   BEC     5387 non-null   int64
# dtypes: int64(2)
# memory usage: 84.3 KB

# %%
hs_bec.to_csv("hs_bec.csv", index = False)
