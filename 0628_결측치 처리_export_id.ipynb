# %%
import pandas as pd
import numpy as np

# %%
#export 파일 불러오기
export_id=pd.read_table('Trade_Map_-_List_of_products_exported_by_India.txt', sep='\t')
export_id.rename(columns={'Code':'HS'}, inplace=True)
export_id.drop(export_id.index[0], inplace=True)
export_id['HS']=export_id['HS'].astype('int64')

# %%
#HS17 코드 불러와서 export 파일과 병합
hs_bec=pd.read_csv('hs_bec17.csv')
export_id=pd.merge(export_id, hs_bec, how='left')

# %%
#최근 10년간 거래가 없는 품목 제외시킴
# no_amount_id=export_id[(export_id['Exported value in 2012']==0)
#                        & (export_id['Exported value in 2013']==0) 
#                        & (export_id['Exported value in 2014']==0) 
#                        & (export_id['Exported value in 2015']==0) 
#                        & (export_id['Exported value in 2016']==0) 
#                        & (export_id['Exported value in 2017']==0)  
#                        & (export_id['Exported value in 2018']==0) 
#                        & (export_id['Exported value in 2019']==0) 
#                        & (export_id['Exported value in 2020']==0) 
#                        & (export_id['Exported value in 2021']==0)].index
# export_id.drop(no_amount_id, inplace=True)
#최근 10년간 거래가 없는 품목 제외시킴
no_amount_id=export_id[(export_id['Exported value in 2017']==0)  
                       & (export_id['Exported value in 2018']==0) 
                       & (export_id['Exported value in 2019']==0) 
                       & (export_id['Exported value in 2020']==0) 
                       & (export_id['Exported value in 2021']==0)].index
export_id.drop(no_amount_id, inplace=True)

# %%
#HS 999999품목은 따로 묶기 위해 임의의 BEC 번호 999999를 만들어 줌
export_id.loc[export_id['HS'] == 999999, 'BEC17'] = 999999

# %%
#BEC17 결측치 확인
export_id[export_id['BEC17'].isnull()]
# Out:
#           HS                                      Product label  \
# 4992  291470  Halogenated, sulphonated, nitrated or nitrosat...
# 5007  300210  Antisera and other blood fractions and immunol...
# 5008  300440  Medicaments containing alkaloids or derivative...
# 5028  441232  Plywood consisting solely of sheets of wood <=...
# 5031  441900  Tableware and kitchenware, of wood (excluding ...
# ...      ...                                                ...
# 5963  847310  Parts and accessories for typewriters or word-...
# 5984  600533  Warp knit fabrics of synthetic fibres, of yarn...
# 6006  441890  Builders' joinery and carpentry, of wood, incl...
# 6035   80520  Fresh or dried mandarins incl. tangerines and ...
# 6082  285300  Inorganic and organic compounds, incl. distill...
#
#       Exported value in 2012  Exported value in 2013  Exported value in 2014  \
# 4992                   64724                   77189                   79706
# ...

# %%
#BEC17 결측치 있는 행들만 모아 데이터 프레임을 만듬(아래에서 BEC12 파일과 병합을 위해)
BEC17_nan_id=export_id[export_id['BEC17'].isnull()]

# %%
#BEC12 파일과 BEC17 결측치가 담긴 데이터프레임을 병합
hs_bec12=pd.read_csv('hs_bec12.csv')
BEC17_nan_id=pd.merge(BEC17_nan_id, hs_bec12, how='left')

# %%
#BEC12와 모두 매치 되어 결측치 없음을 확인
BEC17_nan_id.isnull().sum()
# Out:
# HS                         0
# Product label              0
# Exported value in 2012     0
# Exported value in 2013     0
# Exported value in 2014     0
# Exported value in 2015     0
# Exported value in 2016     0
# Exported value in 2017     0
# Exported value in 2018     0
# Exported value in 2019     0
# Exported value in 2020     0
# Exported value in 2021     0
# Unnamed: 12               64
# BEC17                     64
# BEC12                      0
# dtype: int64

# %%
#BEC17_nan_id[BEC17_nan_id['BEC17'].isnull()]
# Out:
#         HS                                      Product label  \
# 0   291470  Halogenated, sulphonated, nitrated or nitrosat...
# 1   300210  Antisera and other blood fractions and immunol...
# 2   300440  Medicaments containing alkaloids or derivative...
# 3   441232  Plywood consisting solely of sheets of wood <=...
# 4   441900  Tableware and kitchenware, of wood (excluding ...
# ..     ...                                                ...
# 59  847310  Parts and accessories for typewriters or word-...
# 60  600533  Warp knit fabrics of synthetic fibres, of yarn...
# 61  441890  Builders' joinery and carpentry, of wood, incl...
# 62   80520  Fresh or dried mandarins incl. tangerines and ...
# 63  285300  Inorganic and organic compounds, incl. distill...
#
#     Exported value in 2012  Exported value in 2013  Exported value in 2014  \
# 0                    64724                   77189                   79706
# ...

# %%
#BEC4 파일과 BEC12 결측치가 담긴 데이터프레임을 병합하고 결측치 확인
# BEC12_nan_id=BEC17_nan_id[BEC17_nan_id['BEC17'].isnull()]
# hs_bec4=pd.read_csv('hs_bec4.csv')
# BEC12_nan_id=pd.merge(BEC12_nan_id, hs_bec4, how='left')
# BEC12_nan_id.isnull().sum()
# Out:
# HS                         0
# Product label              0
# Exported value in 2012     0
# Exported value in 2013     0
# Exported value in 2014     0
# Exported value in 2015     0
# Exported value in 2016     0
# Exported value in 2017     0
# Exported value in 2018     0
# Exported value in 2019     0
# Exported value in 2020     0
# Exported value in 2021     0
# Unnamed: 12               64
# BEC17                     64
# BEC12                      0
# BEC4                      64
# dtype: int64

# %%
#BEC17로 채워진 행들(export_id)과 BEC12(BEC17_nan_id)로 채워진 행들을 합치기
export_id_complete=pd.merge(export_id, BEC17_nan_id, how='left')

# %%
#컬럼들을 보기 좋게 배열하기 위해 컬럼명 확인
export_id_complete.columns
# Out:
# Index(['HS', 'Product label', 'Exported value in 2012',
#        'Exported value in 2013', 'Exported value in 2014',
#        'Exported value in 2015', 'Exported value in 2016',
#        'Exported value in 2017', 'Exported value in 2018',
#        'Exported value in 2019', 'Exported value in 2020',
#        'Exported value in 2021', 'Unnamed: 12', 'BEC17', 'BEC12'],
#       dtype='object')

# %%
export_id_complete=export_id_complete[['HS', 'BEC17', 'BEC12', 'Product label', 'Exported value in 2012',
       'Exported value in 2013', 'Exported value in 2014',
       'Exported value in 2015', 'Exported value in 2016',
       'Exported value in 2017', 'Exported value in 2018',
       'Exported value in 2019', 'Exported value in 2020',
       'Exported value in 2021', 'Unnamed: 12']]

# %%
export_id_complete
# Out:
#           HS     BEC17  BEC12  \
# 0     271019  213101.0    NaN
# 1     710239  411210.0    NaN
# 2     271012  213101.0    NaN
# 3     300490  711220.0    NaN
# 4     711319  413202.0    NaN
# ...      ...       ...    ...
# 5234  271091    2111.0    NaN
# 5235  370255  611220.0    NaN
# 5236  292330  211220.0    NaN
# 5237  860390  512020.0    NaN
# 5238  890392     512.0    NaN
#
#                                           Product label  \
# 0     Medium oils and preparations, of petroleum or ...
# 1     Diamonds, worked, but not mounted or set (excl...
# 2     Light oils and preparations, of petroleum or b...
# 3     Medicaments consisting of mixed or unmixed pro...
# 4     Articles of jewellery and parts thereof, of pr...
# ...                                                 ...
# 5234  Waste oils containing polychlorinated biphenyl...
# 5235  Photographic film, sensitised, in rolls, unexp...
# 5236      Tetraethylammonium perfluorooctane sulphonate
# ...

# %%
#BEC17 컬럼과 BEC12 컬럼을 합쳐주기 위해 결측치를 0으로 처리
export_id_complete['BEC17']=export_id_complete['BEC17'].fillna(0)
export_id_complete['BEC12']=export_id_complete['BEC12'].fillna(0)
#BEC17 컬럼과 BEC12 컬럼의 값을 더해서 BEC 컬럼을 만들고 기존의 BEC17 컬럼과 BEC12 컬럼은 제외
export_id_complete['BEC']=export_id_complete['BEC17']+export_id_complete['BEC12']
export_id_complete=export_id_complete.drop(columns=['BEC17','BEC12'])

# %%
export_id_complete=export_id_complete[['HS', 'BEC','Product label', 'Exported value in 2012',
       'Exported value in 2013', 'Exported value in 2014',
       'Exported value in 2015', 'Exported value in 2016',
       'Exported value in 2017', 'Exported value in 2018',
       'Exported value in 2019', 'Exported value in 2020',
       'Exported value in 2021', 'Unnamed: 12']]

# %%
export_id_complete
# Out:
#           HS       BEC                                      Product label  \
# 0     271019  213101.0  Medium oils and preparations, of petroleum or ...
# 1     710239  411210.0  Diamonds, worked, but not mounted or set (excl...
# 2     271012  213101.0  Light oils and preparations, of petroleum or b...
# 3     300490  711220.0  Medicaments consisting of mixed or unmixed pro...
# 4     711319  413202.0  Articles of jewellery and parts thereof, of pr...
# ...      ...       ...                                                ...
# 5234  271091    2111.0  Waste oils containing polychlorinated biphenyl...
# 5235  370255  611220.0  Photographic film, sensitised, in rolls, unexp...
# 5236  292330  211220.0      Tetraethylammonium perfluorooctane sulphonate
# 5237  860390  512020.0  Self-propelled railway or tramway coaches, van...
# 5238  890392     512.0  Motor boats and motor yachts, for pleasure or ...
#
#       Exported value in 2012  Exported value in 2013  Exported value in 2014  \
# ...

# %%
export_id_complete.to_csv("export_id.csv", index = False)
