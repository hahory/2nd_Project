# %%
import pandas as pd

# %%
hs_bec=pd.read_csv('hs_bec.csv')
hs_bec
# Out:
#           HS     BEC
# 0      10121  712010
# 1      10129    1111
# 2      10130    1111
# 3      10190    1111
# 4      10221  112010
# ...      ...     ...
# 5382  970200  713202
# 5383  970300  713202
# 5384  970400  813202
# 5385  970500  713202
# 5386  970600  713202
#
# [5387 rows x 2 columns]

# %%
data_cn_raw = pd.read_table('Trade_Map_-_List_of_products_exported_by_China.txt', sep = '\t')

# %%
data_cn_raw
# Out:
#         Code                                      Product label  \
# 0      TOTAL                                       All products
# 1     851712  Telephones for cellular networks ""mobile tele...
# 2     847130  Data-processing machines, automatic, portable,...
# 3     854232         Electronic integrated circuits as memories
# 4     851770  Parts of telephone sets, telephones for cellul...
# ...      ...                                                ...
# 6087  910891  Watch movements, complete and assembled, with ...
# 6088  930529  Parts and accessories for sporting, hunting an...
# 6089  940151                          Seats of bamboo or rattan
# 6090  950350              Toy musical instruments and apparatus
# 6091  961420                       Smoking pipes and pipe bowls
#
#       Exported value in 2012  Exported value in 2013  Exported value in 2014  \
# 0                 2048782200              2209007300              2342292696
# ...

# %%
data_cn=data_cn_raw.drop([0])

# %%
data_cn.rename(columns={'Code':'HS'}, inplace=True)

# %%
data_cn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6091 entries, 1 to 6091
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   HS                      6091 non-null   object
#  1   Product label           6091 non-null   object
#  2   Exported value in 2012  6091 non-null   int64
#  3   Exported value in 2013  6091 non-null   int64
#  4   Exported value in 2014  6091 non-null   int64
#  5   Exported value in 2015  6091 non-null   int64
#  6   Exported value in 2016  6091 non-null   int64
#  7   Exported value in 2017  6091 non-null   int64
#  8   Exported value in 2018  6091 non-null   int64
#  9   Exported value in 2019  6091 non-null   int64
#  10  Exported value in 2020  6091 non-null   int64
#  11  Exported value in 2021  6091 non-null   int64
#  12  Unnamed: 12             0 non-null      float64
# dtypes: float64(1), int64(10), object(2)
# memory usage: 666.2+ KB

# %%
data_cn['HS']=data_cn['HS'].astype('int64') #hs_bec와 data_au를 병합하기 위해 데이터 타입 int64로 변경
data_cn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6091 entries, 1 to 6091
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   HS                      6091 non-null   int64
#  1   Product label           6091 non-null   object
#  2   Exported value in 2012  6091 non-null   int64
#  3   Exported value in 2013  6091 non-null   int64
#  4   Exported value in 2014  6091 non-null   int64
#  5   Exported value in 2015  6091 non-null   int64
#  6   Exported value in 2016  6091 non-null   int64
#  7   Exported value in 2017  6091 non-null   int64
#  8   Exported value in 2018  6091 non-null   int64
#  9   Exported value in 2019  6091 non-null   int64
#  10  Exported value in 2020  6091 non-null   int64
#  11  Exported value in 2021  6091 non-null   int64
#  12  Unnamed: 12             0 non-null      float64
# dtypes: float64(1), int64(11), object(1)
# memory usage: 666.2+ KB

# %%
export_cn=pd.merge(hs_bec,data_cn) #hs_bec와 data_au를 병합

# %%
export_cn
# Out:
#           HS     BEC                                      Product label  \
# 0      10121  712010                          Pure-bred breeding horses
# 1      10129    1111     Live horses (excluding pure-bred for breeding)
# 2      10130    1111                                         Live asses
# 3      10190    1111                             Live mules and hinnies
# 4      10221  112010                      Pure-bred cattle for breeding
# ...      ...     ...                                                ...
# 5215  970200  713202        Original engravings, prints and lithographs
# 5216  970300  713202  Original sculptures and statuary, in any material
# 5217  970400  813202  Postage or revenue stamps, stamp-postmarks, fi...
# 5218  970500  713202  Collections and collector's pieces of zoologic...
# 5219  970600  713202                        Antiques of > 100 years old
#
#       Exported value in 2012  Exported value in 2013  Exported value in 2014  \
# ...

# %%
export_cn.isnull().sum()
# Out:
# HS                           0
# BEC                          0
# Product label                0
# Exported value in 2012       0
# Exported value in 2013       0
# Exported value in 2014       0
# Exported value in 2015       0
# Exported value in 2016       0
# Exported value in 2017       0
# Exported value in 2018       0
# Exported value in 2019       0
# Exported value in 2020       0
# Exported value in 2021       0
# Unnamed: 12               5220
# dtype: int64
