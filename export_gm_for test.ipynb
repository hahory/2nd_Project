# %%
import pandas as pd

# %%
hs_bec=pd.read_csv('hs_bec.csv')
hs_bec
# Out:
#           HS     BEC
# 0      10121  712010
# 1      10129    1111
# 2      10130    1111
# 3      10190    1111
# 4      10221  112010
# ...      ...     ...
# 5382  970200  713202
# 5383  970300  713202
# 5384  970400  813202
# 5385  970500  713202
# 5386  970600  713202
#
# [5387 rows x 2 columns]

# %%
data_gm_raw = pd.read_table('Trade_Map_-_List_of_products_exported_by_Germany.txt', sep = '\t')

# %%
data_gm_raw
# Out:
#         Code                                      Product label  \
# 0      TOTAL                                       All products
# 1     999999                Commodities not elsewhere specified
# 2     300490  Medicaments consisting of mixed or unmixed pro...
# 3     870323  Motor cars and other motor vehicles principall...
# 4     300215  Immunological products, put up in measured dos...
# ...      ...                                                ...
# 6192  851730      Telephonic or telegraphic switching apparatus
# 6193  851790  Parts of electrical apparatus for line telepho...
# 6194  845699  Machine-tools for working any material by remo...
# 6195  845290  Furniture, bases and covers for sewing machine...
# 6196  846920  Typewriters, electric (excluding automatic typ...
#
#       Exported value in 2012  Exported value in 2013  Exported value in 2014  \
# 0                 1410146321              1450937515              1498238432
# ...

# %%
data_gm=data_gm_raw.drop([0])

# %%
data_gm.rename(columns={'Code':'HS'}, inplace=True)

# %%
data_gm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6196 entries, 1 to 6196
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   HS                      6196 non-null   object
#  1   Product label           6196 non-null   object
#  2   Exported value in 2012  6196 non-null   int64
#  3   Exported value in 2013  6196 non-null   int64
#  4   Exported value in 2014  6196 non-null   int64
#  5   Exported value in 2015  6196 non-null   int64
#  6   Exported value in 2016  6196 non-null   int64
#  7   Exported value in 2017  6196 non-null   int64
#  8   Exported value in 2018  6196 non-null   int64
#  9   Exported value in 2019  6196 non-null   int64
#  10  Exported value in 2020  6196 non-null   int64
#  11  Exported value in 2021  6196 non-null   int64
#  12  Unnamed: 12             0 non-null      float64
# dtypes: float64(1), int64(10), object(2)
# memory usage: 677.7+ KB

# %%
data_gm['HS']=data_gm['HS'].astype('int64') #data_gm과 hs_bec를 병합하기 위해 데이터 타입 int64로 변경
data_gm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6196 entries, 1 to 6196
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   HS                      6196 non-null   int64
#  1   Product label           6196 non-null   object
#  2   Exported value in 2012  6196 non-null   int64
#  3   Exported value in 2013  6196 non-null   int64
#  4   Exported value in 2014  6196 non-null   int64
#  5   Exported value in 2015  6196 non-null   int64
#  6   Exported value in 2016  6196 non-null   int64
#  7   Exported value in 2017  6196 non-null   int64
#  8   Exported value in 2018  6196 non-null   int64
#  9   Exported value in 2019  6196 non-null   int64
#  10  Exported value in 2020  6196 non-null   int64
#  11  Exported value in 2021  6196 non-null   int64
#  12  Unnamed: 12             0 non-null      float64
# dtypes: float64(1), int64(11), object(1)
# memory usage: 677.7+ KB

# %%
export_gm=pd.merge(data_gm, hs_bec,how='left') #data_gm과 hs_bec를 병합

# %%
export_gm
# Out:
#           HS                                      Product label  \
# 0     999999                Commodities not elsewhere specified
# 1     300490  Medicaments consisting of mixed or unmixed pro...
# 2     870323  Motor cars and other motor vehicles principall...
# 3     300215  Immunological products, put up in measured dos...
# 4     870340  Motor cars and other motor vehicles principall...
# ...      ...                                                ...
# 6191  851730      Telephonic or telegraphic switching apparatus
# 6192  851790  Parts of electrical apparatus for line telepho...
# 6193  845699  Machine-tools for working any material by remo...
# 6194  845290  Furniture, bases and covers for sewing machine...
# 6195  846920  Typewriters, electric (excluding automatic typ...
#
#       Exported value in 2012  Exported value in 2013  Exported value in 2014  \
# 0                   59373193                63816786                70174563
# ...

# %%
export_gm.isnull().sum()
# Out:
# HS                           0
# Product label                0
# Exported value in 2012       0
# Exported value in 2013       0
# Exported value in 2014       0
# Exported value in 2015       0
# Exported value in 2016       0
# Exported value in 2017       0
# Exported value in 2018       0
# Exported value in 2019       0
# Exported value in 2020       0
# Exported value in 2021       0
# Unnamed: 12               6196
# BEC                        884
# dtype: int64

# %%
no_amount_gm=export_gm[(export_gm['Exported value in 2017']==0) 
& (export_gm['Exported value in 2018']==0)
& (export_gm['Exported value in 2019']==0)
& (export_gm['Exported value in 2020']==0)
& (export_gm['Exported value in 2021']==0)
]
len(no_amount_gm.index)
# Out:
# 1019

# %%
export_gm.drop(no_amount_gm.index, inplace=True) #2017-2021년 사이 거래가 없는 품목 제외

# %%
len(export_gm.index)
# Out:
# 5177

# %%
export_gm.isnull().sum()
# Out:
# HS                           0
# Product label                0
# Exported value in 2012       0
# Exported value in 2013       0
# Exported value in 2014       0
# Exported value in 2015       0
# Exported value in 2016       0
# Exported value in 2017       0
# Exported value in 2018       0
# Exported value in 2019       0
# Exported value in 2020       0
# Exported value in 2021       0
# Unnamed: 12               5177
# BEC                          1
# dtype: int64

# %%
export_gm[export_gm['BEC'].isnull()] #BEC 결측치 1개 gm
# Out:
#        HS                        Product label  Exported value in 2012  \
# 0  999999  Commodities not elsewhere specified                59373193
#
#    Exported value in 2013  Exported value in 2014  Exported value in 2015  \
# 0                63816786                70174563                64670995
#
#    Exported value in 2016  Exported value in 2017  Exported value in 2018  \
# 0                63831190                58021514                60664181
#
#    Exported value in 2019  Exported value in 2020  Exported value in 2021  \
# 0                57559330                46910555                63274483
#
#    Unnamed: 12  BEC
# 0          NaN  NaN

# %%
export_gm['BEC']=export_gm['BEC'].astype('str')

# %%
export_gm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5177 entries, 0 to 6194
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   HS                      5177 non-null   int64
#  1   Product label           5177 non-null   object
#  2   Exported value in 2012  5177 non-null   int64
#  3   Exported value in 2013  5177 non-null   int64
#  4   Exported value in 2014  5177 non-null   int64
#  5   Exported value in 2015  5177 non-null   int64
#  6   Exported value in 2016  5177 non-null   int64
#  7   Exported value in 2017  5177 non-null   int64
#  8   Exported value in 2018  5177 non-null   int64
#  9   Exported value in 2019  5177 non-null   int64
#  10  Exported value in 2020  5177 non-null   int64
#  11  Exported value in 2021  5177 non-null   int64
#  12  Unnamed: 12             0 non-null      float64
#  13  BEC                     5177 non-null   object
# ...

# %%
BEC_group=export_gm['BEC'].str[0] #BEC 첫 숫자를 기준으로 BEC 분야별 구분

# %%
BEC1=export_gm[BEC_group=='1']
BEC2=export_gm[BEC_group=='2'] 
BEC3=export_gm[BEC_group=='3'] 
BEC4=export_gm[BEC_group=='4'] 
BEC5=export_gm[BEC_group=='5'] 
BEC6=export_gm[BEC_group=='6'] 
BEC7=export_gm[BEC_group=='7'] 
BEC8=export_gm[BEC_group=='8'] 
BEC9=export_gm[BEC_group=='9']
BEC_NaN=export_gm[BEC_group=='n']

# %%
BEC1
# Out:
#           HS                                      Product label  \
# 52    210690                          Food preparations, n.e.s.
# 74    842230  Machinery for filling, closing, sealing or lab...
# 80    190590  Bread, pastry, cakes, biscuits and other baker...
# 92     40690  Cheese (excluding fresh cheese, incl. whey che...
# 98    230910            Dog or cat food, put up for retail sale
# ...      ...                                                ...
# 5934   30497  Frozen meat, whether or not minced, of rays an...
# 6051  120300                                              Copra
# 6053  160563  Jellyfish, prepared or preserved (excluding sm...
# 6071   20840  Fresh, chilled or frozen meat and edible offal...
# 6076   50710  Ivory, unworked or simply prepared, its powder...
#
#       Exported value in 2012  Exported value in 2013  Exported value in 2014  \
# 52                   2872678                 3190597                 3368444
# ...

# %%
BEC1=BEC1.iloc[:,2:12]

# %%
BEC1
# Out:
#      Exported value in 2012  Exported value in 2013  Exported value in 2014  \
# 80                  2449296                 2682244                 2652899
# 92                  2702473                 3107497                 2932475
# 98                   999170                 1152495                 1425972
# 117                 2384588                 2602007                 2539856
# 118                 1766969                 1928747                 2166157
# 131                 2282063                 2449539                 2580732
# 133                 1545926                 1634651                 1503785
# 153                 2188310                 2677122                 3037626
# 158                 1299851                 1498811                 1642684
# 172                 1104237                 1148113                 1258081
#
#      Exported value in 2015  Exported value in 2016  Exported value in 2017  \
# ...

# %%
BEC1.sum(axis=0)

# %%
BEC1.loc['sum',:]=BEC1.sum

# %%
BEC1
